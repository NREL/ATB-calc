# %%
import pandas as pd
pd.set_option('display.max_colwidth', 0)
pd.set_option('display.max_columns', 15)
pd.set_option('display.max_rows', 50)
pd.set_option('display.width', 1000)

from tech_processors import LandBasedWindProc, OffShoreWindProc, HydropowerProc, \
    GeothermalProc, UtilityPvProc, ResPvProc, CommPvProc, CoalProc, NaturalGasProc, \
    NuclearProc, BiopowerProc, \
    DistributedWindProc, PumpedStorageHydroProc, UtilityPvPlusBatteryProc,\
    UtilityBatteryProc, CommBatteryProc, ResBatteryProc, CspProc,\
    CoalRetrofitProc, NaturalGasFuelCellProc
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# new_ss = '../../datamaster_working/2021-ATB-Data_Master_v_158_w_new_format.xlsx'
# new_ss = '../2023-ATB-Data_Master_v5.1.xlsx'
new_ss = '../../20230719-ATB-Data_Master.xlsx'
# proc = OffShoreWindProc(new_ss, case='R&D')
# proc = UtilityPvProc(new_ss, crp=20, case='R&D')
# proc = NaturalGasProc(new_ss, crp=30, case='R&D')
# proc = GeothermalProc(new_ss, case='R&D')
proc = GeothermalProc(new_ss, crp=20, case='Market')
# proc = PumpedStorageHydroProc(new_ss, crp=20, case='Market')
# proc = NuclearProc(new_ss, crp=30, case='Market')
#proc = NuclearProc(new_ss, crp=30, case='Market')
# proc = DistributedWindProc(new_ss, crp=20, case='Market')
# proc = BiopowerProc(new_ss, crp=20, case='R&D')
# proc = HydropowerProc(new_ss, case='Market')
# proc = CoalProc(new_ss, crp='TechLife', case='R&D')
# proc = UtilityPvProc(new_ss, case='Market')
# proc = UtilityPvPlusBatteryProc(new_ss, crp=20, case='R&D')
# proc = LandBasedWindProc(new_ss, crp=30, case='Market')
# proc = UtilityBatteryProc(new_ss)
# proc = CommBatteryProc(new_ss, case='Market')
# proc = ResBatteryProc(new_ss, case='R&D')
# proc = ResPvProc(new_ss, case='Market')
# proc = CommPvProc(new_ss, case='Market')
# proc = CspProc(new_ss, case='Market')
#proc = DistributedWindProc(new_ss, case='Market')
# proc = CoalRetrofitProc(new_ss, case='R&D')
# proc = NaturalGasFuelCellProc(new_ss, case='R&D')

proc.get_meta_data()
# Out:
# Loading data from Geothermal, for Market and 20
# 	Loading metrics
# 	Loading assumptions
# 	Loading WACC data
# 	Done loading data
#                              Name               Tech    Resource    Scale Maturity
# 0  Geothermal - Hydro / Flash      Hydro / Flash      Geothermal  Utility  Y
# 1  Geothermal - Hydro / Binary     Hydro / Binary     Geothermal  Utility  Y
# 2  Geothermal - NF EGS / Flash     NF EGS / Flash     Geothermal  Utility  N
# 3  Geothermal - NF EGS / Binary    NF EGS / Binary    Geothermal  Utility  N
# 4  Geothermal - Deep EGS / Flash   Deep EGS / Flash   Geothermal  Utility  N
# 5  Geothermal - Deep EGS / Binary  Deep EGS / Binary  Geothermal  Utility  N

# %%
proc.run()
proc.test_capex()
proc.test_lcoe()
x = proc.flat
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 proc.run()
# ----> 2 proc.test_capex()
#       3 proc.test_lcoe()
#       4 x = proc.flat
#
# File ~/projects/atb/atb_datamaster_etl/lcoe_calculator/base_processor.py:264, in TechProcessor.test_capex(self)
#     262     print('Calculated CAPEX matches CAPEX from spreadsheet')
#     263 else:
# --> 264     raise ValueError('Calculated CAPEX doesn\'t match CAPEX from spreadsheet')
#
# ValueError: Calculated CAPEX doesn't match CAPEX from spreadsheet

# %%
print(x)
# Out:
#              Parameter Case  CRPYears      Technology            DisplayName      Scenario      2021  ...      2044      2045      2046      2047      2048      2049      2050
# 0   Heat Rate           R&D  30        Coal_Retrofits  Retrofit-Coal-95%-CCS  Advanced      11.612    ...  10.871    10.871    10.871    10.871    10.871    10.871    10.871
# 1   Heat Rate           R&D  30        Coal_Retrofits  Retrofit-Coal-95%-CCS  Moderate      11.612    ...  11.241    11.241    11.241    11.241    11.241    11.241    11.241
# 2   Heat Rate           R&D  30        Coal_Retrofits  Retrofit-Coal-95%-CCS  Conservative  11.612    ...  11.612    11.612    11.612    11.612    11.612    11.612    11.612
# 3   Heat Rate           R&D  30        Coal_Retrofits  Retrofit-Coal-99%-CCS  Advanced      11.793    ...  10.990    10.990    10.990    10.990    10.990    10.990    10.990
# ...

# %%
proc.df_c
# Out:
#                                  2021        2022        2023        2024        2025        2026        2027  ...        2044        2045        2046        2047        2048        2049        2050
# tech_detail-scenario                                                                                           ...
# CSP - Class 2/Advanced      431.77998  410.670736  389.561493  368.45225   347.343006  326.233763  305.124519  ...  199.482351  196.459891  193.437431  190.414971  187.392511  184.370051  181.347592
# CSP - Class 2/Moderate      431.77998  417.387314  402.994648  388.601982  374.209316  359.81665   345.423984  ...  272.021387  269.862487  267.703588  265.544688  263.385788  261.226888  259.067988
# CSP - Class 2/Conservative  431.77998  431.77998   431.77998   431.77998   431.77998   431.77998   431.77998   ...  431.77998   431.77998   431.77998   431.77998   431.779980  431.779980  431.779980
# ...

# %%
s = proc.ss_lcoe
s.iloc[0,0] = np.nan
s
# Out:
#                                  2021       2022       2023       2024       2025       2026       2027  ...        2044        2045        2046        2047        2048        2049        2050
# tech_detail-scenario                                                                                     ...
# CSP - Class 2/Advanced      NaN        71.047954  68.789217  65.475956  61.977065  58.478175  54.979287  ...  40.435516   42.154976   45.375743   44.779137   44.182531   43.585925   42.989321
# CSP - Class 2/Moderate      74.001332  72.105192  70.943928  68.717623  66.299284  63.880946  61.462607  ...  53.354518   56.079094   60.927177   60.531614   60.136051   59.740489   59.344926
# CSP - Class 2/Conservative  74.001332  74.473524  75.766812  75.972519  75.972472  75.972422  75.972368  ...  81.336235   86.222175   94.611931   94.611854   94.611776   94.611696   94.611615
# ...

# %%
proc.ss_lcoe.compare(proc.df_lcoe)
proc.ss_lcoe

import numpy as np
np.isclose(np.array(proc.df_lcoe.values, dtype=float), np.array(proc.ss_lcoe.values, dtype=float)).all()
# Out:
# True

# %%
proc.ss_lcoe.values
# Out:
# array([[74.0013324268849, 71.04795362305201, 68.78921690163337,
#         65.47595617330636, 61.97706456136579, 58.47817481612181,
#         54.97928715974002, 51.480401851097184, 47.981519193691,
#         44.482639545686396, 44.01652092496154, 43.55040259280938,
#         43.08428455519831, 42.61816681826254, 42.1520493883079,
#         41.68593227181756, 41.2198154754588, 40.753699006089136,
#         40.2875828707634, 39.821467076741, 39.35535163149309,
#         38.889236542710336, 38.4231218183114, 40.43551622016312,
#         42.15497646003925, 45.375743207772246, 44.77913670195342,
#         44.182530762006365, 43.58592540108579, 42.98932063275741],
#        [74.0013324268849, 72.10519158086252, 70.9439284466623,
#         68.71762315213824, 66.29928430451272, 63.88094559973927,
#         61.462607054819514, 59.04426868956435, 56.62593052719954,
#         54.207592595134024, 53.905245358782345, 53.60289814680978,
# ...

# %%
proc.df_lcoe[:5]
# Out:
#                                        2020        2021        2022        2023        2024        2025       2026       2027       2028       2029  ...       2041       2042       2043       2044       2045       2046       2047       2048       2049       2050
# tech_detail-scenario                                                                                                                                 ...
# Hydropower - NPD 1/Advanced      66.770284   66.770284   66.770284   66.770284   66.770284   66.770284   66.316809  65.863333  65.409857  64.956382  ...  57.689525  57.689525  57.689525  57.689525  57.689525  57.689525  57.689525  57.689525  57.689525  57.689525
# Hydropower - NPD 1/Moderate      66.770284   66.770284   66.770284   66.770284   66.770284   66.770284   66.770285  66.770286  66.770286  66.770287  ...  64.099476  64.099476  64.099476  64.099476  64.099476  64.099476  64.099476  64.099476  64.099476  64.099476
# ...

# %%
proc.df_tc
# Out:
#                               2020      2021      2022      2023      2024      2025      2026      2027      2028      2029  ...         2041         2042         2043         2044         2045         2046         2047      2048      2049      2050
# Tax Credit                                                                                                                    ...
# 10 year CRF/Advanced      0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  ...  0.116085     0.116085     0.116085     0.116085     0.116085     0.116085     0.116085     0.116085  0.116085  0.116085
# 10 year CRF/Moderate      0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  0.116085  ...  0.116085     0.116085     0.116085     0.116085     0.116085     0.116085     0.116085     0.116085  0.116085  0.116085
# ...

# %%
proc.df_cff
# Out:
#                                      2020      2021      2022      2023      2024      2025      2026      2027      2028      2029  ...      2041      2042      2043      2044      2045      2046      2047      2048      2049      2050
# tech_detail-scenario                                                                                                                 ...
# Hydropower - NPD 1/Advanced      1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  ...  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348
# Hydropower - NPD 1/Moderate      1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  ...  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348  1.045348
# ...

# %%
print(np.allclose(51.00001, 51.1))
print(np.allclose(51.00001, 51.01))
print(np.allclose(51.00001, 51.001))
print(np.allclose(51.00001, 51.0001))
print(np.allclose(51.00001, 51.00001))
# Out:
# False
# False
# False
# True
# True
